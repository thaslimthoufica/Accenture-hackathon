# %% [markdown]
# <a href="https://colab.research.google.com/github/thaslimthoufica/Accenture-hackathon/blob/main/front_ui_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-cpp-python transformers accelerate sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 9.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...

# %%
pip install Streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load Mistral model and tokenizer from Hugging Face
model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, device_map="auto")

# Define prompt
prompt = "Explain what an AI agent is"

# Tokenize input
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

# Generate response
outputs = model.generate(**inputs, max_length=200)
response = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print response
print("AI response:", response)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
# !pip install pyngrok

# %%
# %%writefile app.py
import streamlit as st

st.title("🤖 Customer Support AI Assistant")
st.write("Ask a question and get help from multiple agents!")

user_input = st.text_input("Your question:")

if user_input:
    st.info("🧠 Summarizer Agent: This is a sample summary.")
    st.success("✅ Action Agent: Reset password identified.")
    st.warning("💡 Recommender Agent: Send password reset link.")
# Out:
# Writing app.py

# %%
# !pip install streamlit pyngrok --quiet

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(page_title="SupportAI", layout="centered")

st.title("💬 Customer Support Assistant")
st.write("Ask your query below and our intelligent agents will collaborate to help you!")

query = st.text_input("Type your issue here...")

if query:
    st.write("Generating response from multi-agent system...")
    # Replace this with actual model/agent call
    st.success("Here is the suggested resolution based on historical data.")
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

# Paste your actual authtoken below inside the quotes
ngrok.set_auth_token("2vJNy187b1ve0mxpdDbDcPlBu95_45ougxLE4UhqdxWSNyYuP")

# %%
# Kill any previous tunnels
# !pkill streamlit

# Run streamlit in background
# !streamlit run app.py &>/content/logs.txt &

# Expose it via ngrok
public_url = ngrok.connect(port='8501')
print(f"Streamlit app is live: {public_url}")
# Out:
# WARNING:pyngrok.process.ngrok:t=2025-04-05T13:24:56+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=1d8acd375cefbc80 err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     556     try:
# --> 557         response = urlopen(request, encoded_data, timeout)
#     558         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
# ...

# %%
with open("app.py", "w") as f:
    f.write("""
import streamlit as st

st.set_page_config(page_title="Hackathon Bot", layout="centered")
st.title("🔧Multi-Agent User query Resolver Chatbot")
st.write("🤖 Enter your query and the agents will respond!")

user_input = st.text_input("💬 Your message:")

if user_input:
    st.write(f'🧠 Agent: Here\\'s a response to "{user_input}"')
""")

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2vJNy187b1ve0mxpdDbDcPlBu95_45ougxLE4UhqdxWSNyYuP")

ngrok.kill()

# Run streamlit app
import subprocess
import threading

def run_app():
    subprocess.run(["streamlit", "run", "app.py"])

thread = threading.Thread(target=run_app)
thread.start()

# Wait a few seconds for the app to start
import time
time.sleep(5)

# Create tunnel
public_url = ngrok.connect(8501)
print("✅ Streamlit app is live at:", public_url)
# Out:
# ✅ Streamlit app is live at: NgrokTunnel: "https://048a-34-90-28-147.ngrok-free.app" -> "http://localhost:8501"

# %%
pip install ollama

# %%
from huggingface_hub import login
login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load model and tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, device_map="auto")

# Define prompt
prompt = "Explain what an AI agent is"

# Tokenize input
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

# Generate response
outputs = model.generate(**inputs, max_length=200)
response = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print response
print("AI response:", response)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:862: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...
